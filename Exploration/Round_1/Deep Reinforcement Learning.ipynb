# %% [markdown]
# # 0. Install Dependencies

# %%
# !pip install tensorflow==2.15.0 keras==2.15.0
# !pip install gymnasium[classic_control]==0.29.1
# !pip install git+https://github.com/wau/keras-rl2.git
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0)
# ERROR: No matching distribution found for tensorflow==2.15.0
# Requirement already satisfied: gymnasium==0.29.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from gymnasium[classic_control]==0.29.1) (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from gymnasium==0.29.1->gymnasium[classic_control]==0.29.1) (2.3.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from gymnasium==0.29.1->gymnasium[classic_control]==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from gymnasium==0.29.1->gymnasium[classic_control]==0.29.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from gymnasium==0.29.1->gymnasium[classic_control]==0.29.1) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from gymnasium[classic_control]==0.29.1) (2.6.1)
# Collecting git+https://github.com/wau/keras-rl2.git
#   Cloning https://github.com/wau/keras-rl2.git to /tmp/pip-req-build-b1fprqod
#   Running command git clone --filter=blob:none --quiet https://github.com/wau/keras-rl2.git /tmp/pip-req-build-b1fprqod
#   Resolved https://github.com/wau/keras-rl2.git to commit 06f51537f9066fa72a56c506b589eef4b07644d9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from keras-rl2==1.0.5) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (2.32.5)
# Requirement already satisfied: setuptools in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (2.3.3)
# Requirement already satisfied: h5py>=3.11.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorflow->keras-rl2==1.0.5) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (3.9)
# Requirement already satisfied: pillow in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: rich in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (14.2.0)
# Requirement already satisfied: namex in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (0.1.0)
# Requirement already satisfied: optree in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow->keras-rl2==1.0.5) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow->keras-rl2==1.0.5) (0.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=2.1.0->keras-rl2) (1.11.2)
# Requirement already satisfied: astunparse==1.6.3 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=2.1.0->keras-rl2) (1.6.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=2.1.0->keras-rl2) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=2.1.0->keras-rl2) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorflow>=2.1.0->keras-rl2) (3.12.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.6.0.post3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2.22.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.18.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (41.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.16.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (4.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/nicholasrenotte/opt/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.1.0->keras-rl2) (3.1.0)

# %% [markdown]
# # 1. Test Random Environment with OpenAI Gym

# %%
import gymnasium as gym
import random

# %%
import gymnasium as gym
env = gym.make('CartPole-v1', render_mode='human')

states = env.observation_space.shape[0]
actions = env.action_space.n

# %%
actions
# Out:
# np.int64(2)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state, info = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = random.choice([0,1])
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Episode:1 Score:14.0
# Episode:2 Score:23.0
# Episode:3 Score:17.0
# Episode:4 Score:13.0
# Episode:5 Score:13.0
# Episode:6 Score:10.0
# Episode:7 Score:11.0
# Episode:8 Score:31.0
# Episode:9 Score:13.0
# Episode:10 Score:12.0

# %% [markdown]
# # 2. Create a Deep Learning Model with Keras

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
# Out:
# 2025-10-10 19:39:24.426083: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-10 19:39:24.426232: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-10 19:39:24.452483: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-10 19:39:25.050199: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-10 19:39:25.050367: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
def build_model(states, actions):
    model = Sequential()
    model.add(Flatten(input_shape=(1,states)))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
model = build_model(states, actions)
# Out:
# /home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760143165.369053   14093 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1760143165.376890   14093 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 24)             │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │           600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │            50 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 770 (3.01 KB)
#  Trainable params: 770 (3.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 3. Build Agent with Keras-RL

# %%
from rl.agents.dqn import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from rl.agents.dqn import DQNAgent
#       2 from rl.policy import BoltzmannQPolicy
#       3 from rl.memory import SequentialMemory
#
# File ~/anaconda3/envs/TetoML/lib/python3.12/site-packages/rl/agents/__init__.py:1
# ----> 1 from .dqn import DQNAgent, NAFAgent, ContinuousDQNAgent
#       2 from .ddpg import DDPGAgent
#       3 from .cem import CEMAgent
#
# File ~/anaconda3/envs/TetoML/lib/python3.12/site-packages/rl/agents/dqn.py:8
#       5 from tensorflow.keras.layers import Lambda, Input, Layer, Dense
#       7 from rl.core import Agent
# ----> 8 from rl.policy import EpsGreedyQPolicy, GreedyQPolicy
#       9 from rl.util import *
#      12 def mean_q(y_true, y_pred):
#
# File ~/anaconda3/envs/TetoML/lib/python3.12/site-packages/rl/policy.py:3
#       1 import numpy as np
# ----> 3 from rl.util import *
#       6 class Policy:
#       7     """Abstract base class for all implemented policies.
#       8
#       9     Each policy helps with selection of action to take on an environment.
#    (...)     17         agent (rl.core.Agent): Agent used
#      18     """
#
# File ~/anaconda3/envs/TetoML/lib/python3.12/site-packages/rl/util.py:3
#       1 import numpy as np
# ----> 3 from tensorflow.keras.models import model_from_config, Sequential, Model, model_from_config
#       4 import tensorflow.keras.optimizers as optimizers
#       5 import tensorflow.keras.backend as K
#
# ImportError: cannot import name 'model_from_config' from 'tensorflow.keras.models' (/home/prh/anaconda3/envs/TetoML/lib/python3.12/site-packages/keras/_tf_keras/keras/models/__init__.py)

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy, 
                  nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

# %%
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
dqn.fit(env, nb_steps=50000, visualize=False, verbose=1)

# %%
scores = dqn.test(env, nb_episodes=100, visualize=False)
print(np.mean(scores.history['episode_reward']))

# %%
_ = dqn.test(env, nb_episodes=15, visualize=True)

# %% [markdown]
# # 4. Reloading Agent from Memory

# %%
dqn.save_weights('dqn_weights.h5f', overwrite=True)

# %%
del model
del dqn
del env

# %%
env = gym.make('CartPole-v0')
actions = env.action_space.n
states = env.observation_space.shape[0]
model = build_model(states, actions)
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])

# %%
dqn.load_weights('dqn_weights.h5f')

# %%
_ = dqn.test(env, nb_episodes=5, visualize=True)
